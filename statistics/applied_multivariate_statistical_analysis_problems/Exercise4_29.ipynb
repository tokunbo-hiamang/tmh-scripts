# %%
import pandas as pd
import pylab
import scipy.stats
import numpy as np
from numpy.linalg import inv
import sklearn
from matplotlib.mlab import PCA

# %%
t=pd.read_csv('/Users/thiamang/Documents/github/personal/python/models/mvdata/T8-4.dat', sep='\s+', header=None, skiprows=0);
t=t.rename(columns={0:'jp_morgan', 1:'citibank', 2:'wells_fargo', 3:'royal', 4:'exxon'});

# %%
cov_t=np.cov(t)

# %%
inv_cov_t=np.linalg.inv(cov_t)

# %%
inv_cov_t
# Out:
# array([[ -7.92193353e+18,   3.16817351e+19,  -9.03810102e+18, ...,
#           2.70069764e+18,   3.02351251e+19,  -3.38636519e+19],
#        [ -5.53712995e+18,   1.18748779e+20,  -6.55692760e+19, ...,
#           1.57840728e+19,   1.11341733e+20,  -5.13314168e+19],
#        [  1.75143240e+17,   7.09626384e+19,  -2.76878854e+19, ...,
#           6.95068312e+18,   5.14299655e+19,  -6.31357060e+19],
#        ...,
#        [  1.63597601e+18,  -1.53946310e+19,   5.10695877e+18, ...,
#          -5.32486732e+18,  -2.29595270e+19,   1.81136238e+19],
#        [  2.11819110e+18,  -2.02219123e+19,   1.34346561e+19, ...,
#          -4.39461396e+18,  -2.23514261e+19,   2.67792526e+19],
#        [  9.98770287e+18,  -1.84392644e+20,   9.40135089e+19, ...,
#          -2.78429206e+19,  -1.70590925e+20,   1.13929294e+20]])

# %%
w,v = np.linalg.eig(inv_cov_t);

# %%
v
# Out:
# array([[-0.06592505+0.j        , -0.04872117-0.02257767j,
#         -0.04872117+0.02257767j, ...,  0.19529971-0.03101101j,
#         -0.16455780+0.j        ,  0.05473112+0.j        ],
#        [-0.21256432+0.j        , -0.26912378+0.01921833j,
#         -0.26912378-0.01921833j, ...,  0.01941056+0.02303749j,
#         -0.07445102+0.j        , -0.13286549+0.j        ],
#        [-0.00235092+0.j        , -0.17521049+0.05517797j,
#         -0.17521049-0.05517797j, ..., -0.06352166+0.01635324j,
#          0.07298146+0.j        ,  0.10039503+0.j        ],
#        ...,
#        [ 0.00890966+0.j        ,  0.03687938+0.01036996j,
#          0.03687938-0.01036996j, ...,  0.02330058-0.04391007j,
#         -0.04064772+0.j        ,  0.07412048+0.j        ],
#        [ 0.02017725+0.j        ,  0.04194548+0.00955367j,
#          0.04194548-0.00955367j, ..., -0.03176445-0.05042822j,
#          0.05887951+0.j        ,  0.04869109+0.j        ],
# ...

# %%
w
# Out:
# array([ -2.27926823e+20 +0.00000000e+00j,
#          9.03312656e+19 +1.52608732e+20j,
#          9.03312656e+19 -1.52608732e+20j,
#         -5.36114240e+19 +4.91059423e+19j,
#         -5.36114240e+19 -4.91059423e+19j,
#         -6.23371259e+19 +0.00000000e+00j,
#          6.70048983e+19 +0.00000000e+00j,
#          4.64722591e+19 +3.63153682e+19j,
#          4.64722591e+19 -3.63153682e+19j,
#         -8.48053444e+18 +5.21616972e+19j,
#         -8.48053444e+18 -5.21616972e+19j,
#         -3.24723816e+19 +0.00000000e+00j,
#          2.86537238e+19 +9.19508181e+18j,
#          2.86537238e+19 -9.19508181e+18j,
#          1.84590569e+19 +1.75190963e+19j,
#          1.84590569e+19 -1.75190963e+19j,
#         -2.42049573e+19 +0.00000000e+00j,
#         -2.04915982e+19 +9.91028595e+18j,
#         -2.04915982e+19 -9.91028595e+18j,
#          2.36116925e+19 +6.30094510e+17j,
#          2.36116925e+19 -6.30094510e+17j,
#          4.49238890e+18 +2.15615178e+19j,
# ...

# %%
results=PCA(t,standardize=True)

# %%
results

# %%
print results

# %%
dir(results)
# Out:
# ['Wt',
#  'Y',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_colinear',
#  'a',
#  'center',
#  'fracs',
#  'mu',
#  'numcols',
#  'numrows',
#  'project',
#  's',
#  'sigma',
#  'standardize']

# %%
print results.Y
# Out:
# [[  7.84070175e-01   1.05108989e+00  -7.14839913e-01   1.08451570e+00
#    -7.01848643e-01]
#  [ -5.68396303e-01  -2.31789243e-01  -7.33540410e-01  -4.47110156e-01
#    -2.75089301e-01]
#  [  5.93608066e-01   4.77049753e-02   1.07108332e+00  -1.35053314e-02
#     3.45149581e-03]
#  [ -2.34360661e-01   1.59966660e+00   1.77043912e-01   1.05408155e+00
#     2.70381146e-02]
#  [ -7.75964899e-01  -1.39648497e+00  -9.67714918e-01   1.53213403e-01
#    -5.62957031e-02]
#  [  3.06833282e-01  -3.81994609e-01  -6.59125631e-01   1.96115013e-01
#     6.57563969e-01]
#  [ -1.49361274e+00   6.35436578e-02  -4.23079271e-02  -9.11775244e-01
#     1.69233574e-01]
#  [ -1.51809558e+00   9.93532208e-01  -4.87973741e-01   1.35470938e+00
#     1.07674763e+00]
#  [  2.15210334e+00   6.85789277e-02   5.67772080e-01  -1.55874986e-01
#    -8.43784887e-01]
#  [  4.21778547e-01   8.63791188e-01  -3.82823354e-01  -8.10675219e-01
#    -8.64306722e-01]
# ...

# %%
results.numcols
# Out:
# 5

# %%
results.numrows
# Out:
# 103

# %%
results.a
# Out:
#      jp_morgan  citibank  wells_fargo     royal     exxon
# 0     0.575112 -0.405743    -0.321734 -1.816209  0.042516
# 1     0.356636  0.765469    -0.523603  0.294162  0.341528
# 2    -0.911745 -0.443756     0.561946 -0.150641 -0.367949
# 3     0.984674 -0.197713     1.056363 -1.214348 -0.397243
# 4     0.468876  0.146154    -0.785836  0.935325  1.334852
# 5     0.437591 -0.613648    -0.668387  0.359354 -0.037915
# 6     0.483592  1.305716     0.430719  0.985672 -0.029260
# 7     2.278022 -0.277071     1.110768  0.085035  0.131422
# 8    -1.708093 -0.690099    -0.646337 -1.263062 -0.536646
# 9    -0.274915  0.970743    -0.515190 -0.909366 -0.603753
# 10   -0.138519 -0.297099    -0.827544 -0.485092 -0.809641
# 11    0.662437  1.623874    -0.509597  1.199301  0.891356
# 12   -0.495091 -0.279692     0.206473  0.834935  0.322219
# 13   -2.254590 -1.359701    -1.062141  1.243652  1.053946
# 14   -1.225358 -0.904574     0.285902 -1.116336 -0.877167
# ...

# %%
results.mu
# Out:
# jp_morgan      0.001063
# citibank       0.000655
# wells_fargo    0.001626
# royal          0.004049
# exxon          0.004039
# dtype: float64

# %%
results.fracs
# Out:
# array([ 0.48745462,  0.28140253,  0.10010255,  0.08000632,  0.05103398])

# %%
results.s
# Out:
# array([ 248.60185854,  143.51529123,   51.05230032,   40.80322182,
#          26.02732808])

# %%
results_sk=sklearn.decomposition.PCA(n_components=None, copy=True, whiten=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-de4bfe6f9090> in <module>()
# ----> 1 results_sk=sklearn.decomposition.PCA(n_components=None, copy=True, whiten=False)
#
# AttributeError: 'module' object has no attribute 'decomposition'
