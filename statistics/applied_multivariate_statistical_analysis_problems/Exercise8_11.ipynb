# %%
# %matplotlib inline

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.mlab import PCA as mlabPCA
from sklearn.decomposition import PCA as sklearnPCA

# %%
t=pd.read_csv('/Users/tokunbohiamang/Documents/github/tmh-scripts/statistics/applied_multivariate_statistical_analysis_problems/wichern_data/T8-5.dat', sep='\s+', header=None, skiprows=0);
t=t.rename(columns={0:'total_pop', 1:'professional', 2:'over_16', 3:'govt', 4:'home_value'});

# %%
t
# Out:
#     total_pop  professional  over_16  govt  home_value
# 0        2.67          5.71    69.02  30.3        1.48
# 1        2.25          4.37    72.98  43.3        1.44
# 2        3.12         10.27    64.94  32.0        2.11
# 3        5.14          7.44    71.29  24.5        1.85
# 4        5.54          9.25    74.94  31.0        2.23
# 5        5.04          4.84    53.61  48.2        1.60
# 6        3.14          4.82    67.00  37.6        1.52
# 7        2.43          2.40    67.20  36.8        1.40
# 8        5.38          4.30    83.03  19.7        2.07
# 9        7.34          2.73    72.60  24.5        1.42
# 10       4.94          4.66    64.32  27.7        1.42
# 11       4.82          4.26    82.64  20.3        1.46
# 12       5.02          4.17    84.25  20.6        1.42
# 13       3.37          1.00    69.93  16.4        1.17
# 14       3.63          6.40    70.31  29.0        2.00
# 15       7.43          6.00    70.53  37.7        1.44
# ...
