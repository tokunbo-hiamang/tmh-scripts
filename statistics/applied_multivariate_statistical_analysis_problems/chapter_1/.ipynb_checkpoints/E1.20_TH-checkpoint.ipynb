# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import orange
# %matplotlib inline

# %%
path="../wichern_data/"
t=pd.read_csv(path+'T11-4.dat', sep='\s+', header=None, skiprows=0);
t=t.rename(columns={0:'x1', 1:'x2', 2:'x3', 3:'x4', 4:'polulation'});
t.to_csv(path+'T11-4.csv')

# %%
t.head()
# Out:
#      x1    x2    x3    x4  polulation
# 0 -0.45 -0.41  1.09  0.45           0
# 1 -0.56 -0.31  1.51  0.16           0
# 2  0.06  0.02  1.01  0.40           0
# 3 -0.07 -0.09  1.45  0.26           0
# 4 -0.10 -0.09  1.56  0.67           0

# %%
ax = Axes3D(plt.gcf())
ax.scatter(t.x1, t.x3, t.x2, c='r')

# %%
ax.scatter(t.x1, t.x2, t.x3)
